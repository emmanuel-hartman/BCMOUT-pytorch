# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import matplotlib.pyplot as plt
import torch
from SPDMatrices import SPDMatrices
S = SPDMatrices(2)
b = S.random(samples=300,bound=1.0)
print(S)
print(S._metric)
print(torch.all(S.belongs(b)))
# Out:
# <SPDMatrices.SPDMatrices object at 0x7fe81924e370>
# <SPDMatrices.WassersteinBuresMetric object at 0x7fe81924e940>
# tensor(True)

# %%
d=S.dissimilarity(b)
plt.matshow(d.numpy())
plt.show()
print(d.shape)
# Out:
# torch.Size([300, 300])

# %%
from sklearn.manifold import TSNE,MDS
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from ConeSpace import ConeOverM
COverS = ConeOverM(S,2)
print(COverS)
print(COverS._metric)
c=COverS.random(100,10)
print(torch.all(COverS.belongs(c)))
# Out:
# <ConeSpace.ConeOverM object at 0x7fe76b181550>
# <ConeSpace.CosBarMetric object at 0x7fe76b181580>
# tensor(True)

# %%
d=COverS.dissimilarity(c)
plt.matshow(d.numpy())
plt.show()
#print(d)

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from MeasureSpace import MeasureSpace
MonS = MeasureSpace(S,4)
print(MonS)
print(MonS._metric)
e = MonS.random(50,20,10)
print(torch.all(MonS.belongs(e)))
# Out:
# <class 'torch.device'>
# <MeasureSpace.MeasureSpace object at 0x7fe748f66970>
# <MeasureSpace.WFRMetric object at 0x7fe748f665b0>
# tensor(True)

# %%
d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
plt.matshow(d.numpy())
plt.show()
#print(d)
# Out:
# 2450/2450

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
