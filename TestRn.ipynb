# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import matplotlib.pyplot as plt
import torch
from Euclidean import Euclidean
Rn = Euclidean(3)
b = Rn.random(samples=10)
print(Rn)
print(Rn._metric)
print(torch.all(Rn.belongs(b)))
# Out:
# <Euclidean.Euclidean object at 0x0000021F70CC4D00>
# <Euclidean.EuclideanMetric object at 0x0000021F6F12C190>
# tensor(True)

# %%
d=Rn.dissimilarity(b)
plt.matshow(d.numpy())
plt.show()
print(d.shape)
# Out:
# torch.Size([10, 10])

# %%
from sklearn.manifold import TSNE,MDS
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from ConeSpace import ConeOverM
COverS = ConeOverM(Rn,1)
print(COverS)
print(COverS._metric)
c=COverS.random(10,10)
print(torch.all(COverS.belongs(c)))
# Out:
# <ConeSpace.ConeOverM object at 0x0000021F777E8BB0>
# <ConeSpace.CosBarMetric object at 0x0000021F777E8D90>
# tensor(True)

# %%
d=COverS.dissimilarity(c)
plt.matshow(d.numpy())
plt.show()
#print(d)

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from MeasureSpace import MeasureSpace
MonS = MeasureSpace(Rn,1)
print(MonS)
print(MonS._metric)
e = MonS.random(10,20,10)
print(torch.all(MonS.belongs(e)))
# Out:
# <MeasureSpace.MeasureSpace object at 0x0000021F7A38E8B0>
# <MeasureSpace.WFRMetric object at 0x0000021F7A38ED30>
# tensor(True)

# %%
d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
plt.matshow(d.numpy())
plt.show()
#print(d)
# Out:
# 90/90

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
