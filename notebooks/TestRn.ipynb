# %%
import os
os.chdir('..')
import matplotlib.pyplot as plt
import torch
from bcmout.Euclidean import Euclidean
Rn = Euclidean(3)
b = Rn.random(samples=10)
print(Rn)
print(Rn._metric)
print(torch.all(Rn.belongs(b)))
# Out:
# <bcmout.Euclidean.Euclidean object at 0x000001E2F02D17F0>
# <bcmout.Euclidean.EuclideanMetric object at 0x000001E2EE7DC5B0>
# tensor(True)

# %%
d=Rn.dissimilarity(b)
plt.matshow(d.numpy())
plt.show()
print(d.shape)
# Out:
# torch.Size([10, 10])
# tensor([[ 0.4974,  0.8673, -0.8881],
#         [ 0.4574,  0.7758, -0.7714],
#         [ 0.4174,  0.6844, -0.6547],
#         [ 0.3774,  0.5929, -0.5380],
#         [ 0.3374,  0.5014, -0.4213],
#         [ 0.2974,  0.4100, -0.3046],
#         [ 0.2574,  0.3185, -0.1879],
#         [ 0.2174,  0.2271, -0.0712],
#         [ 0.1774,  0.1356,  0.0455],
#         [ 0.1374,  0.0441,  0.1622]])

# %%
from sklearn.manifold import TSNE,MDS
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from ConeSpace import ConeOverM
COverS = ConeOverM(Rn,1)
print(COverS)
print(COverS._metric)
c=COverS.random(1000,10)
print(torch.all(COverS.belongs(c)))
# Out:
# <ConeSpace.ConeOverM object at 0x7fcf49b854c0>
# <ConeSpace.CosBarMetric object at 0x7fcf49b853d0>
# tensor(True)

# %%
d=COverS.dissimilarity(c)
plt.matshow(d.numpy())
plt.show()
#print(d)

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from MeasureSpace import MeasureSpace
MonS = MeasureSpace(Rn,4)
print(MonS)
print(MonS._metric)
e = MonS.random(100,20,10)
print(torch.all(MonS.belongs(e)))
# Out:
# <class 'torch.device'>
# <MeasureSpace.MeasureSpace object at 0x7fcf37cb29d0>
# <MeasureSpace.WFRMetric object at 0x7fcf37cb2d30>
# tensor(True)

# %%
d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
plt.matshow(d.numpy())
plt.show()
#print(d)
# Out:
# 9900/9900

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
