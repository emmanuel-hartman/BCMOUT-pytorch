# %%
import os
os.chdir('..')
import matplotlib.pyplot as plt
import torch
from bcmout.Euclidean import Euclidean
Rn = Euclidean(3)
b = Rn.random(samples=10)
print(Rn)
print(Rn._metric)
print(torch.all(Rn.belongs(b)))
# Out:
# <bcmout.Euclidean.Euclidean object at 0x000001F349A1A7C0>
# <bcmout.Euclidean.EuclideanMetric object at 0x000001F3499CE940>
# tensor(True)
# <bcmout.Euclidean.Euclidean object at 0x000001F349A1A7C0>
# <bcmout.Euclidean.EuclideanMetric object at 0x000001F3499CE940>
# tensor(True)

# %%
d=Rn.dissimilarity(b)
plt.matshow(d.numpy())
plt.show()
print(d.shape)
# Out:
# torch.Size([10, 10])
# torch.Size([10, 10])

# %%
from sklearn.manifold import TSNE,MDS
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from bcmout.ConeSpace import ConeOverM
COverS = ConeOverM(Rn,1)
print(COverS)
print(COverS._metric)
c=COverS.random(1000,10)
print(torch.all(COverS.belongs(c)))
# Out:
# <bcmout.ConeSpace.ConeOverM object at 0x000001F35366E8E0>
# <bcmout.ConeSpace.CosBarMetric object at 0x000001F35366EEB0>
# tensor(True)
# <bcmout.ConeSpace.ConeOverM object at 0x000001F35366E8E0>
# <bcmout.ConeSpace.CosBarMetric object at 0x000001F35366EEB0>
# tensor(True)

# %%
d=COverS.dissimilarity(c)
plt.matshow(d.numpy())
plt.show()
#print(d)

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()

# %%
from bcmout.MeasureSpace import MeasureSpace
MonS = MeasureSpace(Rn,4,)
print(MonS)
print(MonS._metric)
e = MonS.random(100,20,10)
print(torch.all(MonS.belongs(e)))
# Out:
# <bcmout.MeasureSpace.MeasureSpace object at 0x000001F349A7DFA0>
# <bcmout.MeasureSpace.WFRMetric object at 0x000001F353654160>
# tensor(True)
# <bcmout.MeasureSpace.MeasureSpace object at 0x000001F349A7DFA0>
# <bcmout.MeasureSpace.WFRMetric object at 0x000001F353654160>
# tensor(True)

# %%
d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
plt.matshow(d.numpy())
plt.show()
#print(d)
# Out:
# 9900/99001133/99005482/9900

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
