# %%
import os
os.chdir('..')
import matplotlib.pyplot as plt
import torch
from bcmout.Euclidean import Euclidean
Rn = Euclidean(3)
b = Rn.random(samples=1000)
print(Rn)
print(Rn._metric)
print(torch.all(Rn.belongs(b)))
# Out:
# <bcmout.Euclidean.Euclidean object at 0x000001FD874169D0>
# <bcmout.EuclideanMetrics.EuclideanMetric object at 0x000001FD8741A400>
# tensor(True)

# %%
d=Rn.dissimilarity(b)
plt.matshow(d.numpy())
plt.show()
print(d.shape)
# Out:
# torch.Size([1000, 1000])

# %%
from sklearn.manifold import TSNE,MDS
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
# Out:
# C:\Users\Dylan\AppData\Roaming\Python\Python38\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
from bcmout.ConeSpace import ConeOverM
COverS = ConeOverM(Rn,1)
print(COverS)
print(COverS._metric)
c=COverS.random(1000,10)
print(torch.all(COverS.belongs(c)))
# Out:
# <bcmout.ConeSpace.ConeOverM object at 0x000001FDA7E38E20>
# <bcmout.ConeSpace.CosBarMetric object at 0x000001FDA7E38EB0>
# tensor(True)

# %%
d=COverS.dissimilarity(c)
plt.matshow(d.numpy())
plt.show()
#print(d)

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
# Out:
# C:\Users\Dylan\AppData\Roaming\Python\Python38\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
from bcmout.MeasureSpace import MeasureSpace
MonS = MeasureSpace(Rn,4)
print(MonS)
print(MonS._metric)
e = MonS.random(100,20,10)
print(torch.all(MonS.belongs(e)))
# Out:
# <bcmout.MeasureSpace.MeasureSpace object at 0x000001FDA855C130>
# None
# tensor(True)

# %%
d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
plt.matshow(d.numpy())
plt.show()
#print(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d = MonS.dissimilarity(e,max_steps=10000,eps=.00001)
#       2 plt.matshow(d.numpy())
#       3 plt.show()
#
# File ~\Documents\BCMOUT-pytorch\bcmout\MeasureSpace.py:80, in MeasureSpace.dissimilarity(self, point1, max_steps, eps)
#      79 def dissimilarity(self,point1,max_steps=10000,eps=1e-5):
# ---> 80     return self._metric.distance(point1,max_steps=10000,eps=1e-5)
#
# AttributeError: 'NoneType' object has no attribute 'distance'

# %%
X_embedded = MDS(n_components=2, dissimilarity='precomputed').fit_transform(d.numpy())
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.scatter(X_embedded[:,0],X_embedded[:,1])
plt.show()
